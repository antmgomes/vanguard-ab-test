# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_final_demo= pd.read_csv("https://drive.google.com/uc?id=1n-do3beXJIXcVdcUp8gAhIb4jbSjomWK")
df_final_exp_clients=pd.read_csv("https://drive.google.com/uc?id=19mSpzew88dgaSQKvpbS1Dt0L7h-WKk50")
df_web_data_1=pd.read_csv("https://drive.google.com/uc?id=1sTNwBd9Gr2_v3eNuAH-YbZ7Jh6YrKTPD")
df_web_data_2=pd.read_csv("https://drive.google.com/uc?id=1dUbosgeNvDPAHe-i761aF-YH20raALek")
df_final_demo
df_final_exp_clients
df_web_data_1

df_web=pd.merge (df_web_data_1,df_web_data_2, on="client_id",how="inner")

# %%
df_web = df_web.drop_duplicates(subset="client_id", keep="first")
df_web
# Out:
#         client_id           visitor_id_x                    visit_id_x  \
# 0          438567  923318467_50708963627  711884648_43943594307_585328
# 84        8932927  485163175_18149554449  883578716_57691052399_945047
# 91        7040762  902221257_68080603586  274733569_31313180309_937996
# 95        3751049  937925261_74821699083   62955241_10402819739_406095
# 207       6653427  477208101_38628877092   379233621_52265281981_75449
# ...           ...                    ...                           ...
# 160701    4352866  654838437_83920540701   336706992_59380692104_91417
# 160710    3054309  429743648_12656366081  783931577_60029727390_806044
# 160760     976646  687767680_83431555267    659183971_52273068076_7972
# 160776    9889375  513284305_44124254613  794542827_25745627069_541653
# 160780    2443347  465784886_73090545671   29485110_67112661133_270151
#
#        process_step_x          date_time_x           visitor_id_y  \
# 0              step_1  2017-04-05 16:06:35  694624747_14580652583
# 84             step_1  2017-04-13 22:37:49  485163175_18149554449
# 91              start  2017-04-19 11:30:16  523639867_19261927263
# 95              start  2017-04-14 20:35:44  937925261_74821699083
# 207           confirm  2017-04-13 16:38:35  715931239_13908957179
# ...               ...                  ...                    ...
# 160701        confirm  2017-04-04 18:10:42  276163000_63583020379
# 160710         step_1  2017-04-04 21:19:16  429743648_12656366081
# 160760         step_1  2017-03-15 18:00:23  872931974_79025113670
# 160776         step_3  2017-04-12 13:06:50  513284305_44124254613
# 160780        confirm  2017-04-03 16:15:56  818414719_69544570654
#
#                           visit_id_y process_step_y          date_time_y
# 0       787486191_38787201768_120150        confirm  2017-06-08 16:46:39
# 84      103652948_14625127290_455632         step_3  2017-05-10 20:15:35
# 91      364310529_85977575920_721331          start  2017-06-14 16:14:24
# 95      628817270_45049432060_475841        confirm  2017-05-15 23:25:48
# 207     306331908_14858001808_462358        confirm  2017-06-03 13:50:23
# ...                              ...            ...                  ...
# 160701  794827339_82620053246_468822        confirm  2017-06-01 19:24:55
# 160710  796830404_29167630180_245219          start  2017-05-10 22:50:34
# 160760   382926642_57649271108_65269        confirm  2017-06-12 17:42:25
# 160776  695865916_90961653118_512906          start  2017-06-14 13:57:49
# 160780  148166449_67114410166_524360        confirm  2017-05-30 19:18:18
#
# [5664 rows x 9 columns]

# %%
df_final_demo["gendr"] = df_final_demo["gendr"].fillna(np.nan)
df_final_demo = df_final_demo.drop_duplicates(subset="client_id", keep="first")
df_final_demo["gendr"].replace("U",np.nan,inplace=True)
df_final_demo
# Out:
# C:\Users\claud\AppData\Local\Temp\ipykernel_36408\2696798803.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final_demo["gendr"].replace("U",np.nan,inplace=True)
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5   NaN        2.0
# 1        2304905             7.0              94.0      58.0   NaN        2.0
# 2        1439522             5.0              64.0      32.0   NaN        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5   NaN        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
df_final_exp_clients
df_final_exp_clients = df_final_exp_clients.drop_duplicates(subset="client_id", keep="first")
df_final_exp_clients
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_master = (
    df_web
    .merge(df_final_demo, on="client_id", how="inner")
    .merge(df_final_exp_clients, on="client_id", how="inner")
)

# %%
df_master = df_web.merge(df_final_exp_clients, on = 'client_id', how = 'left').merge(df_final_demo, on = 'client_id', how = 'left')

# %%
df_master['date_time_x'] = pd.to_datetime(df_master['date_time_x'], errors='coerce')
df_master['date_time_y'] = pd.to_datetime(df_master['date_time_y'], errors='coerce')
df_master.drop_duplicates(subset='client_id', inplace=True)
df_master["time_diff"]= df_master["date_time_y"]-df_master["date_time_x"]
df_master["time_diff"].describe
# Out:
# <bound method NDFrame.describe of 0      64 days 00:40:04
# 1      26 days 21:37:46
# 2      56 days 04:44:08
# 3      31 days 02:50:04
# 4      50 days 21:11:48
#              ...
# 5659   58 days 01:14:13
# 5660   36 days 01:31:18
# 5661   88 days 23:42:02
# 5662   63 days 00:50:59
# 5663   57 days 03:02:22
# Name: time_diff, Length: 5664, dtype: timedelta64[ns]>

# %%
df_master['session_duration'] = (df_master.groupby('client_id')['date_time_y'].transform('max') - df_master.groupby('client_id')['date_time_x'].transform('min'))
df_master['session_minutes'] = df_master['session_duration'].dt.total_seconds() / 60
df_master['session_minutes'].describe()
# Out:
# count      5664.000000
# mean      63745.546054
# std       25164.155193
# min           6.466667
# 25%       44676.879167
# 50%       62778.450000
# 75%       82470.958333
# max      139564.916667
# Name: session_minutes, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df_master.boxplot(column='session_minutes', by='Variation', grid=False)
plt.title('Distribución del tiempo por diseño')
plt.suptitle('')
plt.xlabel('Variación')
plt.ylabel('Tiempo de sesión (minutos)')
plt.show()

# %%
#not longer than a day 
df_clean = df_master[df_master['session_minutes'] < 1440]

# %%
df_master
# Out:
#       client_id           visitor_id_x                    visit_id_x  \
# 0        438567  923318467_50708963627  711884648_43943594307_585328
# 1       8932927  485163175_18149554449  883578716_57691052399_945047
# 2       7040762  902221257_68080603586  274733569_31313180309_937996
# 3       3751049  937925261_74821699083   62955241_10402819739_406095
# 4       6653427  477208101_38628877092   379233621_52265281981_75449
# ...         ...                    ...                           ...
# 5659    4352866  654838437_83920540701   336706992_59380692104_91417
# 5660    3054309  429743648_12656366081  783931577_60029727390_806044
# 5661     976646  687767680_83431555267    659183971_52273068076_7972
# 5662    9889375  513284305_44124254613  794542827_25745627069_541653
# 5663    2443347  465784886_73090545671   29485110_67112661133_270151
#
#      process_step_x         date_time_x           visitor_id_y  \
# 0            step_1 2017-04-05 16:06:35  694624747_14580652583
# 1            step_1 2017-04-13 22:37:49  485163175_18149554449
# 2             start 2017-04-19 11:30:16  523639867_19261927263
# 3             start 2017-04-14 20:35:44  937925261_74821699083
# 4           confirm 2017-04-13 16:38:35  715931239_13908957179
# ...             ...                 ...                    ...
# 5659        confirm 2017-04-04 18:10:42  276163000_63583020379
# 5660         step_1 2017-04-04 21:19:16  429743648_12656366081
# 5661         step_1 2017-03-15 18:00:23  872931974_79025113670
# 5662         step_3 2017-04-12 13:06:50  513284305_44124254613
# 5663        confirm 2017-04-03 16:15:56  818414719_69544570654
#
#                         visit_id_y process_step_y         date_time_y  \
# 0     787486191_38787201768_120150        confirm 2017-06-08 16:46:39
# 1     103652948_14625127290_455632         step_3 2017-05-10 20:15:35
# 2     364310529_85977575920_721331          start 2017-06-14 16:14:24
# 3     628817270_45049432060_475841        confirm 2017-05-15 23:25:48
# 4     306331908_14858001808_462358        confirm 2017-06-03 13:50:23
# ...                            ...            ...                 ...
# 5659  794827339_82620053246_468822        confirm 2017-06-01 19:24:55
# 5660  796830404_29167630180_245219          start 2017-05-10 22:50:34
# 5661   382926642_57649271108_65269        confirm 2017-06-12 17:42:25
# 5662  695865916_90961653118_512906          start 2017-06-14 13:57:49
# 5663  148166449_67114410166_524360        confirm 2017-05-30 19:18:18
#
#      Variation  ...  clnt_tenure_mnth  clnt_age  gendr num_accts        bal  \
# 0         Test  ...             186.0      38.0      M       2.0   89161.52
# 1          NaN  ...               NaN       NaN    NaN       NaN        NaN
# 2      Control  ...             124.0      54.0      M       2.0   35221.44
# 3      Control  ...              68.0      28.0    NaN       2.0   31050.95
# 4         Test  ...             282.0      52.5      F       3.0  561725.24
# ...        ...  ...               ...       ...    ...       ...        ...
# 5659       NaN  ...             351.0      58.5      F       2.0   60278.74
# 5660       NaN  ...             130.0      57.0      M       2.0  102470.45
# 5661       NaN  ...              74.0      27.0    NaN       2.0   54171.84
# 5662       NaN  ...             194.0      40.0      F       2.0   19097.56
# 5663       NaN  ...             204.0      52.5      M       3.0  164693.48
#
#       calls_6_mnth  logons_6_mnth        time_diff session_duration  \
# 0              6.0            9.0 64 days 00:40:04 64 days 00:40:04
# 1              NaN            NaN 26 days 21:37:46 26 days 21:37:46
# 2              2.0            5.0 56 days 04:44:08 56 days 04:44:08
# 3              5.0            8.0 31 days 02:50:04 31 days 02:50:04
# 4              5.0            8.0 50 days 21:11:48 50 days 21:11:48
# ...            ...            ...              ...              ...
# 5659           3.0            3.0 58 days 01:14:13 58 days 01:14:13
# 5660           4.0            4.0 36 days 01:31:18 36 days 01:31:18
# 5661           7.0            7.0 88 days 23:42:02 88 days 23:42:02
# 5662           2.0            2.0 63 days 00:50:59 63 days 00:50:59
# 5663           7.0            7.0 57 days 03:02:22 57 days 03:02:22
#
#      session_minutes
# 0       92200.066667
# 1       38737.766667
# 2       80924.133333
# 3       44810.066667
# 4       73271.800000
# ...              ...
# 5659    83594.216667
# 5660    51931.300000
# 5661   128142.033333
# 5662    90770.983333
# 5663    82262.366667
#
# [5664 rows x 21 columns]

# %%
#KPIs:
# 1. Complete rate
# 2. Time Spent per step -- per design (only  in the ones that are completed?)
# 3. Where they drop off?
# 4. % of drop off?
#out liers

# %%
# 3. Where they drop off?
step_order = ['start', 'step_1', 'step_2', 'step_3', 'confirm']
step_counts = df_master.groupby(['Variation','process_step_x'])['client_id'].nunique().unstack('Variation').reindex(step_order)
step_counts
# Out:
# Variation       Control  Test
# process_step_x
# start               940  2006
# step_1              287   568
# step_2              182   267
# step_3              249   337
# confirm             185   643

# %%
step_percentage = (step_counts / step_counts.iloc[0]) * 100
step_percentage
# Out:
# Variation          Control        Test
# process_step_x
# start           100.000000  100.000000
# step_1           30.531915   28.315055
# step_2           19.361702   13.310070
# step_3           26.489362   16.799601
# confirm          19.680851   32.053838

# %%
#in which step do we loss more people
#diff between start= start - step_1 .... 69%
# We loss 69% in between those steps

drop_off = step_percentage.diff(-1).abs()
drop_off
# Out:
# Variation         Control       Test
# process_step_x
# start           69.468085  71.684945
# step_1          11.170213  15.004985
# step_2           7.127660   3.489531
# step_3           6.808511  15.254237
# confirm               NaN        NaN

# %%
drop_off.plot(kind='bar', figsize=(8,5), title='Drop-off por paso y variación')
plt.ylabel('% de usuarios perdidos respecto al paso siguiente')
plt.xlabel('Paso del proceso')
plt.show()

# %%
#4. At which step in the process are most users quitting before completion?
max_step = df_master['process_step_x'].max()
max_step

df_master["completed"]= (df_master["process_step_x"]==max_step).astype(int)
df_master["error"]= (df_master["process_step_x"]<max_step).astype(int)
completation_rate= df_master.groupby("Variation")["completed"].mean()*100
completation_rate
# Out:
# Variation
# Control    13.510581
# Test        7.780083
# Name: completed, dtype: float64

# %%
error_rate = df_master.groupby('Variation')['error'].mean() * 100
error_rate
# Out:
# Variation
# Control    86.489419
# Test       92.219917
# Name: error, dtype: float64

# %%
avg_time = df_clean.groupby('Variation')['session_minutes'].mean()
avg_time
# Out:
# Variation
# Control    951.583333
# Test       783.438889
# Name: session_minutes, dtype: float64

# %%
kpi_df = pd.concat([completation_rate, error_rate], axis=1)
kpi_df.columns = ['Completion Rate (%)', 'Error Rate (%)']
print(kpi_df)
# Out:
#            Completion Rate (%)  Error Rate (%)
# Variation
# Control              13.510581       86.489419
# Test                  7.780083       92.219917

# %%
import matplotlib.pyplot as plt

# %%
ax = kpi_df.plot(
    kind='bar',
    figsize=(8, 5),
    title='KPI Comparison by Variation',
)
plt.ylabel('%')
plt.ylim(0, 100)
plt.xticks(rotation=0)
plt.legend(title='KPI')

for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', label_type='edge')

plt.show()

# %%
#Variation fillna with mode
mode_value=df_master["Variation"].mode(dropna=True)[0]
df_master["Variation"].fillna(mode_value, inplace=True)

#clnt_tenure_yr  & clnt_tenure_mnth
df_master[["clnt_tenure_yr", "clnt_tenure_mnth"]].isna().sum()
only_one_missing = ((df_master["clnt_tenure_yr"].isna()) ^ (df_master["clnt_tenure_mnth"].isna())).sum()
print(f" one missing: {only_one_missing}")

cols= ["clnt_tenure_yr", "clnt_tenure_mnth"]
for col in cols:
    clean_data=df_master[col].dropna()

    mean = clean_data.mean()
    std = clean_data.std()
    median = clean_data.median()
    mode = clean_data.mode()[0]
    n_missing=df_master[col].isna().sum()

    if n_missing > 0:
        #filll values without changing the stats of the column, it fill it with random values and 
        random_fill = np.random.normal(loc=mean, scale=std, size=n_missing)
        #limit the values to a range 
        random_fill = np.clip(random_fill, clean_data.min(), clean_data.max())
        df_master.loc[df_master[col].isna(), col] = random_fill

#clnt_age  
col_age=["clnt_age"]
for col in col_age:
    clean_age=df_master[col].dropna()  

    mean = clean_age.mean()
    std = clean_age.std()
    median = clean_age.median()
    mode = clean_age.mode()[0]
    n_missing=df_master[col].isna().sum()

    if n_missing > 0:
        random_fill = np.random.normal(loc=mean, scale=std, size=n_missing)
        df_master.loc[df_master[col].isna(), col] = random_fill
print(df_master[col_age].isna().sum())
# Out:
#  one missing: 0
# clnt_age    0
# dtype: int64
# C:\Users\claud\AppData\Local\Temp\ipykernel_36408\46479834.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_master["Variation"].fillna(mode_value, inplace=True)

# %%
df_master['Variation'].unique()
# Out:
# array(['Test', 'Control'], dtype=object)

# %%
df_master.columns
# Out:
# Index(['client_id', 'visitor_id_x', 'visit_id_x', 'process_step_x',
#        'date_time_x', 'visitor_id_y', 'visit_id_y', 'process_step_y',
#        'date_time_y', 'Variation', 'clnt_tenure_yr', 'clnt_tenure_mnth',
#        'clnt_age', 'gendr', 'num_accts', 'bal', 'calls_6_mnth',
#        'logons_6_mnth', 'time_diff', 'session_duration', 'session_minutes',
#        'completed', 'error'],
#       dtype='object')
